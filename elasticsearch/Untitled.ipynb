# %%
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q

# %%
client = Elasticsearch('67a7441549120daa2dbeef8ac4f5bb2e.us-east-1.aws.found.io:9243')

# %%
help(client.indices)
# Out:
# Help on IndicesClient in module elasticsearch.client.indices object:
#
# class IndicesClient(elasticsearch.client.utils.NamespacedClient)
#  |  Method resolution order:
#  |      IndicesClient
#  |      elasticsearch.client.utils.NamespacedClient
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  analyze(self, index=None, body=None, params=None)
#  |      Perform the analysis process on a text and return the tokens breakdown of the text.
#  |      `<http://www.elastic.co/guide/en/elasticsearch/reference/current/indices-analyze.html>`_
#  |
#  |      :arg index: The name of the index to scope the operation
#  |      :arg body: The text on which the analysis should be performed
#  |      :arg analyzer: The name of the analyzer to use
#  |      :arg attributes: A comma-separated list of token attributes to output,
#  |          this parameter works only with `explain=true`
#  |      :arg char_filter: A comma-separated list of character filters to use for
# ...

# %%
r = client.indices.get_mapping()
r
# Out:
# GET http://67a7441549120daa2dbeef8ac4f5bb2e.us-east-1.aws.found.io:9243/_mapping [status:N/A request:0.505s]
# Traceback (most recent call last):
#   File "/Users/Alexandre/anaconda/lib/python3.5/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/Alexandre/anaconda/lib/python3.5/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/Alexandre/anaconda/lib/python3.5/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/Alexandre/anaconda/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/Users/Alexandre/anaconda/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/Alexandre/anaconda/lib/python3.5/http/client.py", line 258, in _read_status
# ...

# %%
client.indices.delete('reestr')
# Out:
# DELETE http://67a7441549120daa2dbeef8ac4f5bb2e.us-east-1.aws.found.io:9243/reestr [status:N/A request:0.488s]
# Traceback (most recent call last):
#   File "/Users/Alexandre/anaconda/lib/python3.5/site-packages/urllib3/connectionpool.py", line 600, in urlopen
#     chunked=chunked)
#   File "/Users/Alexandre/anaconda/lib/python3.5/site-packages/urllib3/connectionpool.py", line 386, in _make_request
#     six.raise_from(e, None)
#   File "<string>", line 2, in raise_from
#   File "/Users/Alexandre/anaconda/lib/python3.5/site-packages/urllib3/connectionpool.py", line 382, in _make_request
#     httplib_response = conn.getresponse()
#   File "/Users/Alexandre/anaconda/lib/python3.5/http/client.py", line 1197, in getresponse
#     response.begin()
#   File "/Users/Alexandre/anaconda/lib/python3.5/http/client.py", line 297, in begin
#     version, status, reason = self._read_status()
#   File "/Users/Alexandre/anaconda/lib/python3.5/http/client.py", line 258, in _read_status
# ...
